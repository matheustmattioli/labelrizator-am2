# %% [markdown]
# # This is a level 1 heading
#
# ## This is a level 2 heading
#
# This is some plain text that forms a paragraph. Add emphasis via **bold** and __bold__, or *italic* and _italic_.
#
# Paragraphs must be separated by an empty line.
#
# * Sometimes we want to include lists.
# * Which can be bulleted using asterisks.
#
# 1. Lists can also be numbered.
# 2. If we want an ordered list.
#
# [It is possible to include hyperlinks](https://www.example.com)
#
# Inline code uses single backticks: `foo()`, and code blocks use triple backticks:
# ```
# bar()
# ```
# Or can be indented by 4 spaces:
#
#     foo()
#
# And finally, adding images is easy: ![Alt text](https://i.kym-cdn.com/entries/icons/mobile/000/035/876/Xu4Jx48.jpg)

# %%
print("Hello World!!")
# Out:
# Hello World!!

# %%
# Instalação dos pacotes
#!pip install scikit-mutilearn
#!pip install scipy
#!pip install pandas
#!pip install matplotlib
#!pip install numpy
#!pip install -U scikit-learn

# %%
# Importando somente o necessário
import scipy
from scipy.io import arff
import pandas as pd
import numpy as np
from collections import defaultdict

# %%
# Cada info tem 2 campos, nome do dataset e a quantidade 
# de colunas no Y
datasetsName = [('birds', 19),
                ('yeast', 14),
                ('flags', 7),
                ('genbase', 27),
                ('emotions', 6)]

# Inicializando as variaveis
data_train = [0, 0, 0, 0, 0]
meta_train = [0, 0, 0, 0, 0]
X_train = [0, 0, 0, 0, 0]
X_test = [0, 0, 0, 0, 0]
Y_train = [0, 0, 0, 0, 0]
Y_test = [0, 0, 0, 0, 0]
data_test = [0, 0, 0, 0, 0]
meta_test = [0, 0, 0, 0, 0]

# %%
for i in range(len(datasetsName)):
    # Carregando o treino
    # dt, mt = scipy.io.arff.loadarff(f'datasets/{datasetsName[i][0]}/{datasetsName[i][0]}-train.arff')
    data_train[i], meta_train[i] = scipy.io.arff.loadarff(f'datasets/{datasetsName[i][0]}/{datasetsName[i][0]}-train.arff')
    X_train[i] = pd.DataFrame(data_train[i])

    # Carregando o teste
    data_test[i], meta_test[i] = scipy.io.arff.loadarff(f'datasets/{datasetsName[i][0]}/{datasetsName[i][0]}-test.arff')
    X_test[i] = pd.DataFrame(data_test[i])

    

    # # Separando o Y do treino
    Y_train[i] = X_train[i].iloc[:,-datasetsName[i][1]:]
    X_train[i].drop(columns=list(Y_train[i].columns), inplace=True)

    # Separando o Y do teste
    Y_test[i] = X_test[i].iloc[:,-datasetsName[i][1]:]
    X_test[i].drop(columns=list(Y_test[i].columns), inplace=True)

# %%
X_train[0]
#Y_train[0]
# Out:
#      audio-ssd1  audio-ssd2  audio-ssd3  audio-ssd4  audio-ssd5  audio-ssd6  \
# 0      0.016521    0.039926    0.089632    0.134119    0.170470    0.176872
# 1      0.006600    0.035984    0.089956    0.123214    0.172273    0.177068
# 2      0.006894    0.017722    0.048062    0.065802    0.103443    0.091397
# 3      0.031046    0.127675    0.221428    0.272707    0.358743    0.349389
# 4      0.064721    0.226644    0.304482    0.274662    0.346980    0.334063
# ..          ...         ...         ...         ...         ...         ...
# 317    0.009148    0.009075    0.015139    0.020908    0.037890    0.036355
# 318    0.025508    0.011626    0.023700    0.030874    0.047864    0.040987
# 319    0.332050    0.053668    0.123005    0.142725    0.178769    0.165174
# 320    0.009871    0.014142    0.030270    0.044325    0.065054    0.060812
# 321    0.030326    0.014676    0.029328    0.038729    0.066666    0.059713
#
# ...

# %%
X_train[1]
# Y_train[1]
# Out:
#           Att1      Att2      Att3      Att4      Att5      Att6      Att7  \
# 0     0.093700  0.139771  0.062774  0.007698  0.083873 -0.119156  0.073305
# 1    -0.022711 -0.050504 -0.035691 -0.065434 -0.084316 -0.378560  0.038212
# 2    -0.090407  0.021198  0.208712  0.102752  0.119315  0.041729 -0.021728
# 3    -0.085235  0.009540 -0.013228  0.094063 -0.013592 -0.030719 -0.116062
# 4    -0.088765 -0.026743  0.002075 -0.043819 -0.005465  0.004306 -0.055865
# ...        ...       ...       ...       ...       ...       ...       ...
# 1495 -0.119784  0.001259 -0.123645 -0.015513 -0.059683  0.091032 -0.043302
# 1496  0.085327  0.058590  0.085268 -0.020897  0.068972  0.030125  0.078056
# 1497  0.082526 -0.095571 -0.022019 -0.046793 -0.038360  0.041084  0.056509
# 1498 -0.130830  0.008868 -0.009457 -0.058930 -0.041224  0.042269  0.117717
# 1499 -0.171578 -0.066536  0.168206  0.246831  0.079555  0.016528 -0.088908
#
# ...

# %%
X_train[2]
# Y_train[2]
# Out:
#     landmass  zone    area  population language religion  bars  stripes  \
# 0       b'4'  b'1'   164.0         7.0     b'8'     b'2'   0.0      0.0
# 1       b'4'  b'4'   111.0         1.0    b'10'     b'5'   0.0     11.0
# 2       b'1'  b'4'     0.0         0.0     b'1'     b'1'   0.0      0.0
# 3       b'1'  b'4'   109.0         8.0     b'2'     b'0'   3.0      0.0
# 4       b'4'  b'4'    10.0         1.0     b'1'     b'5'   0.0      5.0
# ..       ...   ...     ...         ...      ...      ...   ...      ...
# 124     b'4'  b'1'   236.0        13.0    b'10'     b'5'   0.0      6.0
# 125     b'3'  b'1'   111.0         9.0     b'5'     b'6'   0.0      3.0
# 126     b'4'  b'2'     0.0         0.0     b'1'     b'1'   0.0      0.0
# 127     b'5'  b'1'   648.0        16.0    b'10'     b'2'   0.0      3.0
# 128     b'4'  b'1'  1222.0        31.0    b'10'     b'1'   0.0      3.0
#
#      colours  circles  crosses  saltires  quarters  sunstars crescent  \
# ...

# %%
X_train[3]
# Y_train[3]
# Out:
#        protein PS00010 PS00011 PS00012 PS00014 PS00017 PS00018 PS00019  \
# 0    b'Q9PQS9'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
# 1    b'P22011'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
# 2    b'P79374'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
# 3    b'P09194'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
# 4    b'P05811'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 458  b'P02509'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
# 459  b'Q61771'   b'NO'   b'NO'   b'NO'   b'NO'  b'YES'   b'NO'   b'NO'
# 460  b'P02520'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
# 461  b'Q15147'   b'NO'   b'NO'   b'NO'   b'NO'  b'YES'   b'NO'   b'NO'
# 462  b'Q9XEL8'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'   b'NO'
#
#     PS00020 PS00021  ... PS50821 PS50822 PS50823 PS50824 PS50825 PS50826  \
# ...

# %%
X_train[4]
# Y_train[4]
# Out:
#      Mean_Acc1298_Mean_Mem40_Centroid  Mean_Acc1298_Mean_Mem40_Rolloff  \
# 0                            0.034741                         0.089665
# 1                            0.081374                         0.272747
# 2                            0.110545                         0.273567
# 3                            0.042481                         0.199281
# 4                            0.074550                         0.140880
# ..                                ...                              ...
# 386                          0.065002                         0.178495
# 387                          0.016210                         0.513427
# 388                          0.042903                         0.089283
# 389                          0.038987                         0.059570
# 390                          0.084866                         0.192814
#
#      Mean_Acc1298_Mean_Mem40_Flux  Mean_Acc1298_Mean_Mem40_MFCC_0  \
# ...
